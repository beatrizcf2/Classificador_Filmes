# %% [markdown]
# **Importando as bibliotecas que serão utilizadas:**

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import statsmodels.api as sm 
from sklearn.model_selection import train_test_split
from datetime import datetime

# %% [markdown]
# **Lendo os data frames:**

# %%
metadados = pd.read_csv('movies_metadata.csv')
metadados.head(3)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
credits = pd.read_csv("credits.csv")
credits.head(3)
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602

# %% [markdown]
# **Concatenando os dois data frames:**

# %%
metadados = metadados.append(credits)
metadados
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45471    NaN                                                NaN       NaN
# 45472    NaN                                                NaN       NaN
# 45473    NaN                                                NaN       NaN
# 45474    NaN                                                NaN       NaN
# 45475    NaN                                                NaN       NaN
#
#                                                   genres  \
# ...

# %%
crew = metadados.crew.dropna()
crew.to_frame()
# Out:
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [45476 rows x 1 columns]

# %%
imdb_id = metadados.imdb_id.dropna()
imdb_id.to_frame()
# Out:
#          imdb_id
# 0      tt0114709
# 1      tt0113497
# 2      tt0113228
# 3      tt0114885
# 4      tt0113041
# ...          ...
# 45461  tt6209470
# 45462  tt2028550
# 45463  tt0303758
# 45464  tt0008536
# 45465  tt6980792
#
# [45449 rows x 1 columns]

# %% [markdown]
# **Selecionando as colunas desejadas:**

# %%
tests = pd.DataFrame()
tests = metadados[["imdb_id","crew"]] 
tests
# Out:
#          imdb_id                                               crew
# 0      tt0114709                                                NaN
# 1      tt0113497                                                NaN
# 2      tt0113228                                                NaN
# 3      tt0114885                                                NaN
# 4      tt0113041                                                NaN
# ...          ...                                                ...
# 45471        NaN  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 45472        NaN  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 45473        NaN  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 45474        NaN  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 45475        NaN  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [90942 rows x 2 columns]

# %%
tests_sem_id_nan = pd.DataFrame()
tests_sem_id_nan = tests.crew.dropna()
tests_sem_id_nan.to_frame()
# Out:
#                                                     crew
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3      [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4      [{'credit_id': '52fe44959251416c75039ed7', 'de...
# ...                                                  ...
# 45471  [{'credit_id': '5894a97d925141426c00818c', 'de...
# 45472  [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 45473  [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 45474  [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 45475  [{'credit_id': '593e676c92514105b702e68e', 'de...
#
# [45476 rows x 1 columns]
